# %%
import pandas as pd
from pycaret.classification import *
import os

# %%
pd.set_option('display.max_columns', None)

# %%
screenshots = pd.read_csv("../images/screenshots/screenshots.csv")

# %%
screenshots_ph = pd.read_csv("../images/screenshots_ph/screenshots_ph.csv")

# %%
regulars = pd.read_csv("../images/regular/regular.csv")

# %%
not_good = pd.read_csv("../images/not_good/not_good.csv")

# %%
superb = pd.read_csv("../images/superb/superb.csv")

# %%
docs = pd.read_csv("../images/docs/docs.csv")

# %%
receipts = pd.read_csv("../images/receipts/receipts.csv")

# %%
test = pd.read_csv("../images/test/test.csv")

# %%
regulars["search"] = 0
not_good["search"] = 0
superb['search'] = 0
screenshots["search"] = 0
docs["search"] = 0
receipts["search"] = 0
screenshots_ph["search"] = 1

# %%
whole_docs = pd.concat([regulars, not_good, superb, screenshots, docs, screenshots_ph, receipts], ignore_index=True)

# %%
whole_docs.describe()
# Out:
#             size_w       size_h  aspect_ratio  mean_value_b  mean_value_g  \
# count   891.000000   891.000000    891.000000    891.000000    891.000000
# mean   2440.396184  2342.511785      1.045797    131.367672    138.050665
# std    1409.085120  1443.415724      0.473753     55.125598     50.577893
# min     220.000000   360.000000      0.373750      0.121475      0.121475
# 25%    1280.000000  1080.000000      0.707361     91.464247    107.801949
# 50%    2246.000000  1864.000000      0.750000    129.793072    136.058008
# 75%    3840.000000  3264.000000      1.336082    165.060959    168.102810
# max    6720.000000  6720.000000      3.598456    253.462925    253.322823
#
#        mean_value_r  median_value_b  median_value_g  median_value_r  \
# count    891.000000      891.000000      891.000000      891.000000
# mean     141.870582      134.542088      142.784512      147.164983
# std       49.730889       69.755538       63.792031       64.124709
# min        0.121475        0.000000        0.000000        0.000000
# 25%      110.664055       81.000000      102.500000      106.000000
# 50%      142.939614      133.000000      141.000000      154.000000
# 75%      172.696894      183.000000      185.000000      188.500000
# max      253.105211      255.000000      255.000000      255.000000
#
#        std_deviation_b  ...     sharpness       gradient  texture_energy  \
# count       891.000000  ...    891.000000     891.000000      891.000000
# mean         55.916484  ...   1032.421654   11680.577244        0.061178
# std          18.500912  ...   2136.013959   15978.422479        0.156737
# min           0.098913  ...      0.009402       0.121187        0.000040
# 25%          44.721001  ...     56.606764    1304.830570        0.000663
# 50%          56.839637  ...    302.081212    5415.181897        0.001563
# 75%          66.998003  ...   1253.983763   15554.867875        0.011567
# max         113.885816  ...  30170.659310  177580.040200        0.991532
#
#        color_balance    focus_score  average_hash         dhash         phash  \
# count     891.000000     891.000000  8.910000e+02  8.910000e+02  8.910000e+02
# mean       55.139080   11680.577244  9.146635e+18  9.842822e+18  1.370458e+19
# std        16.970162   15978.422479  7.690783e+18  5.768360e+18  2.609503e+18
# min         0.098913       0.121187  0.000000e+00  0.000000e+00  9.224071e+18
# 25%        43.751716    1304.830570  5.062366e+17  4.706880e+18  1.146630e+19
# 50%        56.413783    5415.181897  9.097054e+18  9.807073e+18  1.392684e+19
# 75%        65.967766   15554.867875  1.817530e+19  1.512569e+19  1.546308e+19
# max       115.693060  177580.040200  1.844674e+19  1.844674e+19  1.843693e+19
#
#           colorhash      search
# count  8.910000e+02  891.000000
# mean   6.942465e+11    0.083053
# std    7.446873e+11    0.276117
# min    1.126400e+04    0.000000
# 25%    4.295974e+11    0.000000
# 50%    4.811391e+11    0.000000
# 75%    5.411659e+11    0.000000
# max    4.011499e+12    1.000000
#
# [8 rows x 51 columns]

# %%
whole_docs.keys()
# Out:
# Index(['size_w', 'size_h', 'aspect_ratio', 'mean_value_b', 'mean_value_g',
#        'mean_value_r', 'median_value_b', 'median_value_g', 'median_value_r',
#        'std_deviation_b', 'std_deviation_g', 'std_deviation_r', 'contrast',
#        'brightness', 'hog_features_mean', 'hog_features_median',
#        'hog_features_std', 'hog_features_len', 'h_mean', 'h_median', 'h_std',
#        's_mean', 's_median', 's_std', 'v_mean', 'v_median', 'v_std',
#        'n_objects', 'area', 'area_mean', 'area_std', 'vert', 'vert_mean',
#        'vert_std', 'color_mean', 'color_std', 'corners', 'lines', 'faces',
#        'has_text', 'filesize', 'sharpness', 'gradient', 'texture_energy',
#        'color_balance', 'focus_score', 'average_hash', 'dhash', 'phash',
#        'colorhash', 'filename', 'search'],
#       dtype='object')

# %%
whole_docs = whole_docs.drop(columns=["filename"])
whole_docs.sample()
# Out:
#      size_w  size_h  aspect_ratio  mean_value_b  mean_value_g  mean_value_r  \
# 172    3024    4032      1.333333     76.363665     74.397697     76.898693
#
#      median_value_b  median_value_g  median_value_r  std_deviation_b  ...  \
# 172            70.0            70.0            76.0        30.858176  ...
#
#      sharpness    gradient  texture_energy  color_balance  focus_score  \
# 172   5.103814  138.090094        0.026435      26.749113   138.090094
#
#      average_hash         dhash                 phash     colorhash  search
# 172  5.046151e+17  1.840990e+19  17879307081802616591  506906804224       0
#
# [1 rows x 51 columns]

# %%
corr = whole_docs.corr()

# %%
corr.search.sort_values()
# Out:
# average_hash          -0.217771
# size_w                -0.196804
# hog_features_len      -0.184851
# size_h                -0.173538
# has_text              -0.159133
# area                  -0.152467
# phash                 -0.126066
# texture_energy        -0.114239
# faces                 -0.102408
# filesize              -0.102036
# color_mean            -0.079155
# area_mean             -0.072651
# s_median              -0.069948
# area_std              -0.065304
# mean_value_r          -0.065303
# color_std             -0.055151
# s_mean                -0.050567
# v_mean                -0.049577
# lines                 -0.038171
# brightness            -0.031969
# median_value_r        -0.028760
# vert_mean             -0.027584
# mean_value_g          -0.019144
# colorhash             -0.013729
# mean_value_b          -0.007158
# v_median              -0.005903
# focus_score           -0.003083
# gradient              -0.003083
# corners                0.015027
# median_value_g         0.020537
# median_value_b         0.022278
# n_objects              0.032859
# aspect_ratio           0.038376
# v_std                  0.047776
# sharpness              0.060912
# hog_features_std       0.061928
# std_deviation_g        0.064314
# std_deviation_r        0.067657
# contrast               0.071764
# color_balance          0.076256
# vert_std               0.080964
# s_std                  0.082297
# std_deviation_b        0.082951
# hog_features_median    0.089042
# vert                   0.091428
# hog_features_mean      0.096317
# h_std                  0.103287
# dhash                  0.110916
# h_median               0.131367
# h_mean                 0.157856
# search                 1.000000
# Name: search, dtype: float64

# %%
s = setup(whole_docs, target = 'search', session_id = 123)
# Out:
# <style type="text/css">
# #T_2fcb4_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2fcb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fcb4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2fcb4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fcb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fcb4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2fcb4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2fcb4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2fcb4_row1_col1" class="data row1 col1" >search</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2fcb4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2fcb4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2fcb4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2fcb4_row3_col1" class="data row3 col1" >(891, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2fcb4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2fcb4_row4_col1" class="data row4 col1" >(891, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2fcb4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2fcb4_row5_col1" class="data row5 col1" >(623, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2fcb4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2fcb4_row6_col1" class="data row6 col1" >(268, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2fcb4_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2fcb4_row7_col1" class="data row7 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2fcb4_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_2fcb4_row8_col1" class="data row8 col1" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2fcb4_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_2fcb4_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2fcb4_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_2fcb4_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2fcb4_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_2fcb4_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2fcb4_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_2fcb4_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2fcb4_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_2fcb4_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2fcb4_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_2fcb4_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2fcb4_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_2fcb4_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2fcb4_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_2fcb4_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2fcb4_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_2fcb4_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2fcb4_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_2fcb4_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2fcb4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2fcb4_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_2fcb4_row19_col1" class="data row19 col1" >33e3</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_not_good = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             10:01:02
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
# <style type="text/css">
# #T_89d54 th {
#   text-align: left;
# }
# #T_89d54_row0_col0, #T_89d54_row0_col1, #T_89d54_row0_col2, #T_89d54_row0_col3, #T_89d54_row0_col4, #T_89d54_row0_col5, #T_89d54_row0_col6, #T_89d54_row0_col7, #T_89d54_row0_col8, #T_89d54_row1_col0, #T_89d54_row1_col1, #T_89d54_row1_col2, #T_89d54_row1_col3, #T_89d54_row1_col4, #T_89d54_row1_col5, #T_89d54_row1_col6, #T_89d54_row1_col7, #T_89d54_row1_col8, #T_89d54_row2_col0, #T_89d54_row2_col1, #T_89d54_row2_col2, #T_89d54_row2_col3, #T_89d54_row2_col4, #T_89d54_row2_col5, #T_89d54_row2_col6, #T_89d54_row2_col7, #T_89d54_row2_col8, #T_89d54_row3_col0, #T_89d54_row3_col1, #T_89d54_row3_col2, #T_89d54_row3_col3, #T_89d54_row3_col4, #T_89d54_row3_col5, #T_89d54_row3_col6, #T_89d54_row3_col7, #T_89d54_row3_col8, #T_89d54_row4_col0, #T_89d54_row4_col1, #T_89d54_row4_col2, #T_89d54_row4_col3, #T_89d54_row4_col4, #T_89d54_row4_col5, #T_89d54_row4_col6, #T_89d54_row4_col7, #T_89d54_row4_col8, #T_89d54_row5_col0, #T_89d54_row5_col1, #T_89d54_row5_col2, #T_89d54_row5_col3, #T_89d54_row5_col4, #T_89d54_row5_col5, #T_89d54_row5_col6, #T_89d54_row5_col7, #T_89d54_row5_col8, #T_89d54_row6_col0, #T_89d54_row6_col1, #T_89d54_row6_col2, #T_89d54_row6_col3, #T_89d54_row6_col4, #T_89d54_row6_col5, #T_89d54_row6_col6, #T_89d54_row6_col7, #T_89d54_row6_col8, #T_89d54_row7_col0, #T_89d54_row7_col1, #T_89d54_row7_col2, #T_89d54_row7_col3, #T_89d54_row7_col4, #T_89d54_row7_col5, #T_89d54_row7_col6, #T_89d54_row7_col7, #T_89d54_row7_col8, #T_89d54_row8_col0, #T_89d54_row8_col1, #T_89d54_row8_col2, #T_89d54_row8_col3, #T_89d54_row8_col4, #T_89d54_row8_col5, #T_89d54_row8_col6, #T_89d54_row8_col7, #T_89d54_row8_col8, #T_89d54_row9_col0, #T_89d54_row9_col1, #T_89d54_row9_col2, #T_89d54_row9_col3, #T_89d54_row9_col4, #T_89d54_row9_col5, #T_89d54_row9_col6, #T_89d54_row9_col7, #T_89d54_row9_col8, #T_89d54_row10_col0, #T_89d54_row10_col1, #T_89d54_row10_col2, #T_89d54_row10_col3, #T_89d54_row10_col4, #T_89d54_row10_col5, #T_89d54_row10_col6, #T_89d54_row10_col7, #T_89d54_row10_col8, #T_89d54_row11_col0, #T_89d54_row11_col1, #T_89d54_row11_col2, #T_89d54_row11_col3, #T_89d54_row11_col4, #T_89d54_row11_col5, #T_89d54_row11_col6, #T_89d54_row11_col7, #T_89d54_row11_col8, #T_89d54_row12_col0, #T_89d54_row12_col1, #T_89d54_row12_col2, #T_89d54_row12_col3, #T_89d54_row12_col4, #T_89d54_row12_col5, #T_89d54_row12_col6, #T_89d54_row12_col7, #T_89d54_row12_col8, #T_89d54_row13_col0, #T_89d54_row13_col1, #T_89d54_row13_col2, #T_89d54_row13_col3, #T_89d54_row13_col4, #T_89d54_row13_col5, #T_89d54_row13_col6, #T_89d54_row13_col7, #T_89d54_row13_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_89d54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89d54_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_89d54_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_89d54_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_89d54_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_89d54_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_89d54_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_89d54_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_89d54_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_89d54_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89d54_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_89d54_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_89d54_row0_col1" class="data row0 col1" >0.9648</td>
#       <td id="T_89d54_row0_col2" class="data row0 col2" >0.9710</td>
#       <td id="T_89d54_row0_col3" class="data row0 col3" >0.6233</td>
#       <td id="T_89d54_row0_col4" class="data row0 col4" >0.9467</td>
#       <td id="T_89d54_row0_col5" class="data row0 col5" >0.7316</td>
#       <td id="T_89d54_row0_col6" class="data row0 col6" >0.7149</td>
#       <td id="T_89d54_row0_col7" class="data row0 col7" >0.7428</td>
#       <td id="T_89d54_row0_col8" class="data row0 col8" >0.6680</td>
#     </tr>
#     <tr>
#       <th id="T_89d54_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_89d54_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_89d54_row1_col1" class="data row1 col1" >0.9615</td>
#       <td id="T_89d54_row1_col2" class="data row1 col2" >0.9728</td>
#       <td id="T_89d54_row1_col3" class="data row1 col3" >0.5400</td>
#       <td id="T_89d54_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_89d54_row1_col5" class="data row1 col5" >0.6877</td>
#       <td id="T_89d54_row1_col6" class="data row1 col6" >0.6704</td>
#       <td id="T_89d54_row1_col7" class="data row1 col7" >0.7121</td>
#       <td id="T_89d54_row1_col8" class="data row1 col8" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_89d54_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_89d54_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_89d54_row2_col1" class="data row2 col1" >0.9552</td>
#       <td id="T_89d54_row2_col2" class="data row2 col2" >0.9564</td>
#       <td id="T_89d54_row2_col3" class="data row2 col3" >0.5833</td>
#       <td id="T_89d54_row2_col4" class="data row2 col4" >0.8600</td>
#       <td id="T_89d54_row2_col5" class="data row2 col5" >0.6771</td>
#       <td id="T_89d54_row2_col6" class="data row2 col6" >0.6549</td>
#       <td id="T_89d54_row2_col7" class="data row2 col7" >0.6780</td>
#       <td id="T_89d54_row2_col8" class="data row2 col8" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_89d54_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_89d54_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_89d54_row3_col1" class="data row3 col1" >0.9535</td>
#       <td id="T_89d54_row3_col2" class="data row3 col2" >0.9511</td>
#       <td id="T_89d54_row3_col3" class="data row3 col3" >0.4867</td>
#       <td id="T_89d54_row3_col4" class="data row3 col4" >0.9417</td>
#       <td id="T_89d54_row3_col5" class="data row3 col5" >0.6159</td>
#       <td id="T_89d54_row3_col6" class="data row3 col6" >0.5958</td>
#       <td id="T_89d54_row3_col7" class="data row3 col7" >0.6444</td>
#       <td id="T_89d54_row3_col8" class="data row3 col8" >0.2300</td>
#     </tr>
#     <tr>
#       <th id="T_89d54_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_89d54_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_89d54_row4_col1" class="data row4 col1" >0.9520</td>
#       <td id="T_89d54_row4_col2" class="data row4 col2" >0.9418</td>
#       <td id="T_89d54_row4_col3" class="data row4 col3" >0.6000</td>
#       <td id="T_89d54_row4_col4" class="data row4 col4" >0.8200</td>
#       <td id="T_89d54_row4_col5" class="data row4 col5" >0.6795</td>
#       <td id="T_89d54_row4_col6" class="data row4 col6" >0.6546</td>
#       <td id="T_89d54_row4_col7" class="data row4 col7" >0.6709</td>
#       <td id="T_89d54_row4_col8" class="data row4 col8" >0.0770</td>
#     </tr>
#     <tr>
#       <th id="T_89d54_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_89d54_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_89d54_row5_col1" class="data row5 col1" >0.9519</td>
#       <td id="T_89d54_row5_col2" class="data row5 col2" >0.9481</td>
#       <td id="T_89d54_row5_col3" class="data row5 col3" >0.4267</td>
#       <td id="T_89d54_row5_col4" class="data row5 col4" >0.9000</td>
#       <td id="T_89d54_row5_col5" class="data row5 col5" >0.5615</td>
#       <td id="T_89d54_row5_col6" class="data row5 col6" >0.5449</td>
#       <td id="T_89d54_row5_col7" class="data row5 col7" >0.5952</td>
#       <td id="T_89d54_row5_col8" class="data row5 col8" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_89d54_level0_row6" class="row_heading level0 row6" >lda</th>
#       <td id="T_8
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]

# %%
tune_model(best_not_good)
# Out:
# <style type="text/css">
# #T_56121_row10_col0, #T_56121_row10_col1, #T_56121_row10_col2, #T_56121_row10_col3, #T_56121_row10_col4, #T_56121_row10_col5, #T_56121_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_56121">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56121_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_56121_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_56121_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_56121_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_56121_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_56121_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_56121_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56121_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56121_row0_col0" class="data row0 col0" >0.9194</td>
#       <td id="T_56121_row0_col1" class="data row0 col1" >0.9750</td>
#       <td id="T_56121_row0_col2" class="data row0 col2" >0.9091</td>
#       <td id="T_56121_row0_col3" class="data row0 col3" >0.7143</td>
#       <td id="T_56121_row0_col4" class="data row0 col4" >0.8000</td>
#       <td id="T_56121_row0_col5" class="data row0 col5" >0.7504</td>
#       <td id="T_56121_row0_col6" class="data row0 col6" >0.7590</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56121_row1_col0" class="data row1 col0" >0.9194</td>
#       <td id="T_56121_row1_col1" class="data row1 col1" >0.9626</td>
#       <td id="T_56121_row1_col2" class="data row1 col2" >0.5455</td>
#       <td id="T_56121_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_56121_row1_col4" class="data row1 col4" >0.7059</td>
#       <td id="T_56121_row1_col5" class="data row1 col5" >0.6638</td>
#       <td id="T_56121_row1_col6" class="data row1 col6" >0.7048</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_56121_row2_col0" class="data row2 col0" >0.8710</td>
#       <td id="T_56121_row2_col1" class="data row2 col1" >0.8164</td>
#       <td id="T_56121_row2_col2" class="data row2 col2" >0.4545</td>
#       <td id="T_56121_row2_col3" class="data row2 col3" >0.7143</td>
#       <td id="T_56121_row2_col4" class="data row2 col4" >0.5556</td>
#       <td id="T_56121_row2_col5" class="data row2 col5" >0.4844</td>
#       <td id="T_56121_row2_col6" class="data row2 col6" >0.5014</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_56121_row3_col0" class="data row3 col0" >0.9194</td>
#       <td id="T_56121_row3_col1" class="data row3 col1" >0.9537</td>
#       <td id="T_56121_row3_col2" class="data row3 col2" >0.7273</td>
#       <td id="T_56121_row3_col3" class="data row3 col3" >0.8000</td>
#       <td id="T_56121_row3_col4" class="data row3 col4" >0.7619</td>
#       <td id="T_56121_row3_col5" class="data row3 col5" >0.7135</td>
#       <td id="T_56121_row3_col6" class="data row3 col6" >0.7147</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_56121_row4_col0" class="data row4 col0" >0.9355</td>
#       <td id="T_56121_row4_col1" class="data row4 col1" >0.9447</td>
#       <td id="T_56121_row4_col2" class="data row4 col2" >0.6364</td>
#       <td id="T_56121_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_56121_row4_col4" class="data row4 col4" >0.7778</td>
#       <td id="T_56121_row4_col5" class="data row4 col5" >0.7422</td>
#       <td id="T_56121_row4_col6" class="data row4 col6" >0.7682</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_56121_row5_col0" class="data row5 col0" >0.9355</td>
#       <td id="T_56121_row5_col1" class="data row5 col1" >0.8983</td>
#       <td id="T_56121_row5_col2" class="data row5 col2" >0.6667</td>
#       <td id="T_56121_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_56121_row5_col4" class="data row5 col4" >0.8000</td>
#       <td id="T_56121_row5_col5" class="data row5 col5" >0.7634</td>
#       <td id="T_56121_row5_col6" class="data row5 col6" >0.7857</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_56121_row6_col0" class="data row6 col0" >0.9355</td>
#       <td id="T_56121_row6_col1" class="data row6 col1" >0.9833</td>
#       <td id="T_56121_row6_col2" class="data row6 col2" >0.6667</td>
#       <td id="T_56121_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_56121_row6_col4" class="data row6 col4" >0.8000</td>
#       <td id="T_56121_row6_col5" class="data row6 col5" >0.7634</td>
#       <td id="T_56121_row6_col6" class="data row6 col6" >0.7857</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_56121_row7_col0" class="data row7 col0" >0.9032</td>
#       <td id="T_56121_row7_col1" class="data row7 col1" >0.8867</td>
#       <td id="T_56121_row7_col2" class="data row7 col2" >0.5833</td>
#       <td id="T_56121_row7_col3" class="data row7 col3" >0.8750</td>
#       <td id="T_56121_row7_col4" class="data row7 col4" >0.7000</td>
#       <td id="T_56121_row7_col5" class="data row7 col5" >0.6450</td>
#       <td id="T_56121_row7_col6" class="data row7 col6" >0.6639</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_56121_row8_col0" class="data row8 col0" >0.9032</td>
#       <td id="T_56121_row8_col1" class="data row8 col1" >0.9300</td>
#       <td id="T_56121_row8_col2" class="data row8 col2" >0.5833</td>
#       <td id="T_56121_row8_col3" class="data row8 col3" >0.8750</td>
#       <td id="T_56121_row8_col4" class="data row8 col4" >0.7000</td>
#       <td id="T_56121_row8_col5" class="data row8 col5" >0.6450</td>
#       <td id="T_56121_row8_col6" class="data row8 col6" >0.6639</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_56121_row9_col0" class="data row9 col0" >0.9355</td>
#       <td id="T_56121_row9_col1" class="data row9 col1" >0.9550</td>
#       <td id="T_56121_row9_col2" class="data row9 col2" >0.7500</td>
#       <td id="T_56121_row9_col3" class="data row9 col3" >0.9000</td>
#       <td id="T_56121_row9_col4" class="data row9 col4" >0.8182</td>
#       <td id="T_56121_row9_col5" class="data row9 col5" >0.7794</td>
#       <td id="T_56121_row9_col6" class="data row9 col6" >0.7841</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_56121_row10_col0" class="data row10 col0" >0.9177</td>
#       <td id="T_56121_row10_col1" class="data row10 col1" >0.9306</td>
#       <td id="T_56121_row10_col2" class="data row10 col2" >0.6523</td>
#       <td id="T_56121_row10_col3" class="data row10 col3" >0.8879</td>
#       <td id="T_56121_row10_col4" class="data row10 col4" >0.7419</td>
#       <td id="T_56121_row10_col5" class="data row10 col5" >0.6950</td>
#       <td id="T_56121_row10_col6" class="data row10 col6" >0.7131</td>
#     </tr>
#     <tr>
#       <th id="T_56121_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_56121_row11_col0" class="data row11 col0" >0.0197</td>
#       <td id="T_56121_row11_col1" class="data row11 col1" >0.0481</td>
#       <td id="T_56121_row11_col2" class="data row11 col2" >0.1191</td>
#       <td id="T_56121_row11_col3" class="data row11 col3" >0.1090</td>
#       <td id="T_56121_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
ids_test = test.pop("filename")

# %%
not_good_pred = predict_model(best_not_good, data=test)

# %%
not_good_pred.sample()
# Out:
#     size_w  size_h  ch  aspect_ratio  mean_value_b  mean_value_g  \
# 60    2016    4032   3           2.0    124.210114    140.406235
#
#     mean_value_r  median_value_b  median_value_g  median_value_r  ...  \
# 60    155.223267           121.0           137.0           155.0  ...
#
#     filesize  depth  sharpness     gradient  texture_energy  texture_contrast  \
# 60   2516117  uint8  58.429031  4398.277344        0.001756               0.0
#
#     color_balance  focus_score  prediction_label  prediction_score
# 60      49.799664  4398.277344                 0            0.9994
#
# [1 rows x 51 columns]

# %%
not_good_pred["name"] = ids_test

# %%
not_good_photos = not_good_pred.loc[not_good_pred.prediction_label == 1 ,["name", "prediction_label", "prediction_score"]]

# %%
not_good_photos
# Out:
#                 name  prediction_label  prediction_score
# 8   regular (10).JPG                 1            0.9976
# 24  not_good (8).JPG                 1            0.9347
# 33  not_good (5).JPG                 1            0.9650
# 42  not_good (9).JPG                 1            0.9986
# 44    superb (1).jpg                 1            0.5244
# 49  not_good (6).JPG                 1            0.9911
# 62  not_good (7).JPG                 1            0.7597
# 63   regular (9).JPG                 1            0.7655
# 64  regular (15).JPG                 1            0.6236
# 68   regular (5).JPG                 1            0.9968
# 88  not_good (1).JPG                 1            0.9966
# 89      docs (7).JPG                 1            0.7145

# %%
if not os.path.isdir("../images/test/1/"):
    os.mkdir("../images/test/1/")
if not os.path.isdir("../images/test/0/"):
    os.mkdir("../images/test/0/")

# %%
def movingImage(filename, location, destination):
    location = location + filename
    destination = destination + filename
    os.rename(location, destination)

# %%
for step in not_good_photos["name"]:
    movingImage(step, "../images/test/", "../images/test/1/")

# %%
not_bad_photos = not_good_pred.loc[not_good_pred.prediction_label == 0 ,["name", "prediction_label", "prediction_score"]]

# %%
for step in not_bad_photos["name"]:
    movingImage(step, "../images/test/", "../images/test/0/")

# %%
not_good_pred
# Out:
#     size_w  size_h  ch  aspect_ratio  mean_value_b  mean_value_g  \
# 0     1280     904   3      0.706250    246.206100    244.809433
# 1     1280     591   3      0.461719    146.109192    153.940399
# 2      878    1594   3      1.815490    222.977325    228.492493
# 3     1268    2102   3      1.657729    243.880280    243.444717
# 4     1280     960   3      0.750000    143.283218    150.069199
# ..     ...     ...  ..           ...           ...           ...
# 85    1270    2362   3      1.859843    235.082870    236.869186
# 86    1038    1850   3      1.782274    247.124176    247.132874
# 87    1600    1200   3      0.750000    139.222885    150.281479
# 88    4032    3024   3      0.750000     66.038475     62.667686
# 89    3120    4160   3      1.333333     77.595284     88.233177
#
#     mean_value_r  median_value_b  median_value_g  median_value_r  ...  depth  \
# 0     244.117859           255.0           255.0           255.0  ...  uint8
# 1     162.087952           173.0           173.0           173.0  ...  uint8
# 2     228.665588           255.0           255.0           255.0  ...  uint8
# 3     242.887512           255.0           255.0           255.0  ...  uint8
# 4     144.446091           149.0           154.0           146.0  ...  uint8
# ..           ...             ...             ...             ...  ...    ...
# 85    235.545029           255.0           255.0           255.0  ...  uint8
# 86    247.097626           255.0           255.0           255.0  ...  uint8
# 87    157.251343           165.0           164.0           164.0  ...  uint8
# 88     69.149940            57.0            56.0            62.0  ...  uint8
# 89     99.026207            74.0            90.0           102.0  ...  uint8
#
#       sharpness      gradient  texture_energy  texture_contrast  \
# 0   1841.777222  33596.929688        0.588539               0.0
# 1   2603.048096  45339.917969        0.102465               0.0
# 2    398.435486  18998.435547        0.286698               0.0
# 3   2035.957520  33824.468750        0.377107               0.0
# 4   1328.645630  10828.695312        0.022690               0.0
# ..          ...           ...             ...               ...
# 85   990.406067  15578.054688        0.323792               0.0
# 86  1777.006836  32144.330078        0.894077               0.0
# 87   176.958405   5317.399414        0.006446               0.0
# 88    77.186325    543.351868        0.001137               0.0
# 89   152.620941   2935.410645        0.000443               0.0
#
#     color_balance   focus_score  prediction_label  prediction_score  \
# 0       40.820488  33596.929688                 0            1.0000
# 1      100.485756  45339.917969                 0            1.0000
# 2       53.538616  18998.435547                 0            1.0000
# 3       39.141560  33824.468750                 0            1.0000
# 4       21.210787  10828.695312                 0            1.0000
# ..            ...           ...               ...               ...
# 85      46.956673  15578.054688                 0            1.0000
# 86      41.519806  32144.330078                 0            1.0000
# 87      39.940491   5317.399414                 0            1.0000
# 88      51.208015    543.351868                 1            0.9966
# 89      37.097515   2935.410645                 1            0.7145
#
#                     name
# 0    screenshots (1).JPG
# 1   screenshots (10).JPG
# 2    screenshots (1).png
# 3   screenshots (10).png
# 4          docs (15).JPG
# ..                   ...
# 85  screenshots (13).png
# 86   screenshots (2).png
# 87         docs (16).JPG
# 88      not_good (1).JPG
# 89          docs (7).JPG
#
# [90 rows x 52 columns]

# %%
evaluate_model(best_not_good)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
